# %%
import geopandas as gpd
import pandas as pd
import requests
import matplotlib.pyplot as plt
url = "https://gist.githubusercontent.com/meganmason/40a87840b52c5516efc716236a67ccf3/raw/9767072779ac6f22d13e5e4dbf2c7e85f3e6e15e/SNEX20_TS_SP_cogm_swe.geojson"
df = gpd.read_file(url)
df
# Out:
#                 Site                 PitID Date/Local Standard Time UTM Zone  \
# 0   County Line Open  COGMCO_20191219_1220      2019-12-19 12:20:00      12N
# 1   County Line Open  COGMCO_20191220_1030      2019-12-20 10:30:00      12N
# 2   County Line Open  COGMCO_20200122_1015      2020-01-22 10:15:00      12N
# 3   County Line Open  COGMCO_20200131_0830      2020-01-31 08:30:00      12N
# 4   County Line Open  COGMCO_20200212_0852      2020-02-12 08:52:00      12N
# ..               ...                   ...                      ...      ...
# 71       Skyway Tree  COGMST_20200421_0726      2020-04-21 07:26:00      12N
# 72       Skyway Tree  COGMST_20200421_1507      2020-04-21 15:07:00      12N
# 73       Skyway Tree  COGMST_20200422_1618      2020-04-22 16:18:00      12N
# 74       Skyway Tree  COGMST_20200503_0653      2020-05-03 06:53:00      12N
# 75       Skyway Tree  COGMST_20200503_1732      2020-05-03 17:32:00      12N
#
#     Easting (m)  Northing (m)  Density Mean (kg/m^3)  Snow Depth (cm)  \
# 0        756848       4324359                  239.0               61
# 1        756902       4324360                  249.5               60
# 2        756902       4324356                  245.0              107
# 3        756906       4324360                  269.0              114
# 4        756901       4324357                  269.0              103
# ..          ...           ...                    ...              ...
# 71       754212       4325899                  326.0              115
# 72       754048       4325618                  295.5              100
# 73       754134       4325810                  321.5              102
# 74       754143       4325838                  327.0               61
# 75       754148       4325844                  333.5               62
#
#     SWE (mm)                     geometry
# 0      146.0  POINT (-108.03281 39.03057)
# 1      150.0  POINT (-108.03218 39.03056)
# 2      261.5  POINT (-108.03218 39.03052)
# 3      306.0  POINT (-108.03214 39.03056)
# 4      276.5  POINT (-108.03219 39.03053)
# ..       ...                          ...
# 71     376.0  POINT (-108.06265 39.04520)
# 72     295.0  POINT (-108.06464 39.04272)
# 73     328.0  POINT (-108.06358 39.04442)
# 74     199.5  POINT (-108.06346 39.04467)
# 75     206.5  POINT (-108.06340 39.04472)
#
# [76 rows x 10 columns]

# %%
# keep columns we want in the dataframe
df = df[['Site', 'Date/Local Standard Time', 'SWE (mm)']]

df = df.rename({'Date/Local Standard Time': 'date', 'SWE (mm)': 'swe (mm)'}, axis=1)
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
mo = df.loc[df['Site'] == 'Mesa West Open']
mt = df.loc[df['Site'] == 'Mesa West Trees']
so = df.loc[df['Site'] == 'Skyway Open']
st = df.loc[df['Site'] == 'Skyway Tree']
co = df.loc[df['Site'] == 'County Line Open']
ct = df.loc[df['Site'] == 'County Line Tree']

# %%
mo.to_csv('../../data/snowpits/mesawest-open_swe.csv', sep=',', index=False, na_rep=' ')
mt.to_csv('../../data/snowpits/mesawest-tree_swe.csv', sep=',', index=False, na_rep=' ')
so.to_csv('../../data/snowpits/skyway-open_swe.csv', sep=',', index=False, na_rep=' ')
st.to_csv('../../data/snowpits/skyway-tree_swe.csv', sep=',', index=False, na_rep=' ')
co.to_csv('../../data/snowpits/countyline-open_swe.csv', sep=',', index=False, na_rep=' ')
ct.to_csv('../../data/snowpits/countyline-tree_swe.csv', sep=',', index=False, na_rep=' ')

# %%
print('script is finish')
# Out:
# script is finish
